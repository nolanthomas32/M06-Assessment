# %%
# from config import dictionaryloc
# from config import turntextloc
# from config import wheeltextloc
# from config import maxrounds
# from config import vowelcost
# from config import roundstatusloc
# from config import finalprize
# from config import finalRoundTextLoc

import config
import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""




wheellist = getattr(config, 'maxrounds', 'no_wheeltext_found' )
print(f'maxrounds = {wheeltextloc}')
# Out:
# maxrounds = data/wheeldata.txt

# %%
f = open('DATA TXT Files\dictionary.txt')
sample = f.read()
f.close()

print(sample)
# Out:
# flute
# piccolo
# clarinet
# oboe
# saxophone
# bassoon
# piano
# percussion
# trumpet
# trombone
# horn
# tuba
# sousaphone
# marimba
# timpani
# vibraphone
# harpsichord
# choir

# %%
# from config import dictionaryloc
# from config import turntextloc
# from config import wheeltextloc
# from config import maxrounds
# from config import vowelcost
# from config import roundstatusloc
# from config import finalprize
# from config import finalRoundTextLoc

import config
import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""




def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close
readRoundStatusTxtFile()
print(roundstatus.format(1, roundNum, 2500, 0))
# Out:
# At the end of round 1 Here are the ranks:
#     Player 1: 0
#     Player 2: 2500
#     Player 3: 0

# %%
txt3 = "My name is {}, I'm {}".format("John",36)
print(txt3)
# Out:
# My name is John, I'm 36

# %%
# from config import dictionaryloc
# from config import turntextloc
# from config import wheeltextloc
# from config import maxrounds
# from config import vowelcost
# from config import roundstatusloc
# from config import finalprize
# from config import finalRoundTextLoc

import config
import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""

def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()  
readTurnTxtFile()
print(turntext.format(1))
# Out:
# Player 1, it's your turn!
# 1: Spin the wheel
# 2: Buy a vowel
# 3: Guess the word

# %%
# from config import dictionaryloc
# from config import turntextloc
# from config import wheeltextloc
# from config import maxrounds
# from config import vowelcost
# from config import roundstatusloc
# from config import finalprize
# from config import finalRoundTextLoc

import config
import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""

def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
readFinalRoundTxtFile()
print(finalroundtext.format(1))
print(type(players))
# Out:
# Congratulations Player 1! You have made it to the Final Round!
# <class 'dict'>

# %%
# from config import dictionaryloc
# from config import turntextloc
# from config import wheeltextloc
# from config import maxrounds
# from config import vowelcost
# from config import roundstatusloc
# from config import finalprize
# from config import finalRoundTextLoc

import config
import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []


for i in range(1,4):
    player_list.append([i])
print((player_list))

# for key in players.keys():
#     player_list.append(f'{key}')
#     print((player_list))

# def getPlayerInfo():
#     global players
#     players.keys()
# Out:
# [[1], [2], [3]]

# %%
# from config import dictionaryloc
# from config import turntextloc
# from config import wheeltextloc
# from config import maxrounds
# from config import vowelcost
# from config import roundstatusloc
# from config import finalprize
# from config import finalRoundTextLoc

import config
import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []

def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

# def getWord():
#     global dictionary
#     #choose random word from dictionary
#     #make a list of the word with underscores instead of letters.
#     return roundWord,roundUnderscoreWord
readDictionaryFile()
print(dictionary_list)
print(type(dictionary_list))
# Out:
# ['flute', 'piccolo', 'clarinet', 'oboe', 'saxophone', 'bassoon', 'piano', 'percussion', 'trumpet', 'trombone', 'horn', 'tuba', 'sousaphone', 'marimba', 'timpani', 'vibraphone', 'harpsichord', 'choir']
# <class 'list'>

# %%
# from config import dictionaryloc
# from config import turntextloc
# from config import wheeltextloc
# from config import maxrounds
# from config import vowelcost
# from config import roundstatusloc
# from config import finalprize
# from config import finalRoundTextLoc

import config
import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []

def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])

def getWord():
    global dictionary
    global roundword
    roundword = random.choice(dictionary_list)
    return roundWord

readDictionaryFile()
getWord()

print(roundword)
# Out:
# flute

# %%
from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []




def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheellist
    f = open('DATA TXT Files\wheeldata.txt')
    wheellist = f.read()
    f.close()
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.
    
gameSetup()
getWord()
print(roundWord)
print(roundUnderscoreWord)
print(type(roundUnderscoreWord))
# Out:
# trombone
# ['_', '_', '_', '_', '_', '_', '_', '_', '']
# <class 'list'>

# %%
from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []




def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheellist
    f = open('DATA TXT Files\wheeldata.txt')
    wheellist = f.read()
    f.close()
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)

wofRoundSetup()
print(initPlayer)

print(players.values())

{'roundtotal': 0, 'gametotal': 0, 'name': ''} in players.values()
# Out:
# [2]
# dict_values([{'roundtotal': 0, 'gametotal': 0, 'name': ''}, {'roundtotal': 0, 'gametotal': 0, 'name': ''}, {'roundtotal': 0, 'gametotal': 0, 'name': ''}])
# True

# %%
from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []




def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheellist
    f = open('DATA TXT Files\wheeldata.txt')
    wheellist = f.read()
    f.close()
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    # players.update({0:{"roundtotal":100}})
    # players.update({1:{"roundtotal":500}})
    # players.update({2:{"roundtotal":3700}})
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)

wofRoundSetup()
print(initPlayer)



# players.update({0:{"roundtotal":0,"gametotal":0,"name":""}})

players.update({0:{"roundtotal":100}})
players.update({1:{"roundtotal":500}})
players.update({2:{"roundtotal":3700}})
print(players)
# Out:
# [2]
# {0: {'roundtotal': 100}, 1: {'roundtotal': 500}, 2: {'roundtotal': 3700}}

# %%
from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []




def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheellist
    f = open('DATA TXT Files\wheeldata.txt')
    wheellist = f.read()
    f.close()
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    # players.update({0:{"roundtotal":100}})
    # players.update({1:{"roundtotal":500}})
    # players.update({2:{"roundtotal":3700}})
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)

wofRoundSetup()
print(initPlayer)



# players.update({0:{"roundtotal":0,"gametotal":0,"name":""}})

players.update({0:{"roundtotal":100}})
players.update({1:{"roundtotal":500}})
players.update({2:{"roundtotal":3700}})
print(players)
print(type(players))
# Out:
# [3]
# {0: {'roundtotal': 100}, 1: {'roundtotal': 500}, 2: {'roundtotal': 3700}}
# <class 'dict'>

# %%
from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
round_winnings = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []




def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheellist
    f = open('DATA TXT Files\wheeldata.txt')
    wheellist = f.read()
    f.close()
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

wofRoundSetup()
print(initPlayer)

round_winning = 2500
players.update({0:{"roundtotal":0,"gametotal":round_winning}})
players.update({1:{"roundtotal":0,"gametotal":0}})
players.update({2:{"roundtotal":0,"gametotal":0}})
print(players)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\nolan\Desktop\Dev10 Training\M06 Python Basics\M06 Assessment\work.ipynb Cell 14 in <cell line: 106>()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=101'>102</a>     return roundWord, roundUnderscoreWord
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=102'>103</a>     #choose random word from dictionary
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=103'>104</a>     #make a list of the word with underscores instead of letters.
# --> <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=105'>106</a> wofRoundSetup()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=106'>107</a> print(initPlayer)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=108'>109</a> round_winning = 2500
#
# c:\Users\nolan\Desktop\Dev10 Training\M06 Python Basics\M06 Assessment\work.ipynb Cell 14 in wofRoundSetup()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=123'>124</a> player_keys = random.choice(player_list)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=124'>125</a> initPlayer = [x+1 for x in {player_keys}]
# --> <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=125'>126</a> getWord()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=126'>127</a> playerNum = initPlayer
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=127'>128</a> return initPlayer
#
# c:\Users\nolan\Desktop\Dev10 Training\M06 Python Basics\M06 Assessment\work.ipynb Cell 14 in getWord()
#      <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=96'>97</a> global roundWord
#      <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=97'>98</a> global roundUnderscoreWord
# ---> <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=98'>99</a> roundWord = random.choice(dictionary_list)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=99'>100</a> roundUnderscoreWord = '_ ' * len(roundWord)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X16sZmlsZQ%3D%3D?line=100'>101</a> roundUnderscoreWord = roundUnderscoreWord.split(' ')
#
# File c:\Users\nolan\AppData\Local\Programs\Python\Python310\lib\random.py:378, in Random.choice(self, seq)
#     376 """Choose a random element from a non-empty sequence."""
#     377 # raises IndexError if seq is empty
# --> 378 return seq[self._randbelow(len(seq))]
#
# IndexError: list index out of range

# %%
from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random

players={0:{"roundtotal":0,"gametotal":0,"name":""},
         1:{"roundtotal":0,"gametotal":0,"name":""},
         2:{"roundtotal":0,"gametotal":0,"name":""},
        }

roundNum = 0
round_winnings = 0
dictionary_list = []
turntext = ""
wheellist = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []




def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheellist
    f = open('DATA TXT Files\wheeldata.txt')
    wheellist = f.read()
    f.close()
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    players.update({0:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({1:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({2:{"roundtotal":0,"gametotal":round_winnings}})
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    getWord()
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)

gameSetup()
wofRoundSetup()
print(initPlayer)
print(players)
print(type(players))
print(roundWord)
print(roundUnderscoreWord)
# Out:
# [1]
# {0: {'roundtotal': 0, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# <class 'dict'>
# timpani
# ['_', '_', '_', '_', '_', '_', '_', '']

# %%
from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random
round_total = 0

players={0:{"roundtotal":round_total,"gametotal":0,"name":""},
         1:{"roundtotal":round_total,"gametotal":0,"name":""},
         2:{"roundtotal":round_total,"gametotal":0,"name":""},
        }

roundNum = 0
round_winnings = 0
dictionary_list = []
turntext = ""
wheel_list = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
roundstatus = ""
finalroundtext = ""
player_list = []




def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheel_list
    f = open('DATA TXT Files\wheeldata.txt')
    wheelvalue = f.read().split('\n')
    f.close()
    for value in range(0,len(wheelvalue)):
        wheel_list.append(wheelvalue[value])
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    global player_keys
    players.update({0:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({1:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({2:{"roundtotal":0,"gametotal":round_winnings}})
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    getWord()
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)

def spinWheel(playerNum):
    global wheel_list
    global players
    global vowels
    global spin_value
    global roundUnderscoreWord
    global round_total
    global consonant_value
    
    stillinTurn = True
    while stillinTurn is True:
        spin_value = random.choice(wheel_list)
        if spin_value == 'bankrupt':
            players.update({"roundtotal":0})
            stillinTurn = False
            print (spin_value)
            continue
        if spin_value == 'lose_a_turn':
            stillinTurn = False
            print(spin_value)
            continue
        else:
            consonant_value = int(spin_value)
            print(spin_value)
            guess = input('Guess your letter')
            if guess.isalpha() is False:
                print('Please guess a letter!')
                continue
            else:
                print(roundWord)
                if guess in roundWord:
                    pos = [i for i in range(len(roundWord)) if roundWord.startswith(guess,i)]
                    guess = list(guess)
                    for i in pos:
                        roundUnderscoreWord = roundUnderscoreWord[:i] + guess + roundUnderscoreWord[i + len(guess):]
                        print (f'The word: {roundUnderscoreWord}')
                        round_total = round_total+consonant_value
                        players.update({0:{"roundtotal":round_total, "gametotal":round_winnings}})
                        continue
                    if "_" not in roundUnderscoreWord:
                        print('The word has been guessed! The round is over!')
                        break
                else:
                    print (f'The word: {roundUnderscoreWord}')
                    stillinTurn = False
    
    # Get random value for wheellist
    # Check for bankrupcy, and take action.
    # Check for lose turn
    # Get amount from wheel if not lose turn or bankruptcy
    # Ask user for letter guess
    # Use guessletter function to see if guess is in word, and return count
    # Change player round total if they guess right. 
        
    return stillinTurn

gameSetup()
wofRoundSetup()
spinWheel(player_keys)
print(players)
# Out:
# 400
# percussion
# The word: ['p', '_', '_', '_', '_', '_', '_', '_', '_', '_', '']
# 900
# percussion
# The word: ['p', 'e', '_', '_', '_', '_', '_', '_', '_', '_', '']
# 600
# percussion
# The word: ['p', 'e', 'r', '_', '_', '_', '_', '_', '_', '_', '']
# 100
# percussion
# The word: ['p', 'e', 'r', 'c', '_', '_', '_', '_', '_', '_', '']
# 450
# percussion
# The word: ['p', 'e', 'r', 'c', 'u', '_', '_', '_', '_', '_', '']
# 100
# percussion
# The word: ['p', 'e', 'r', 'c', 'u', 's', '_', '_', '_', '_', '']
# The word: ['p', 'e', 'r', 'c', 'u', 's', 's', '_', '_', '_', '']
# 300
# percussion
# The word: ['p', 'e', 'r', 'c', 'u', 's', 's', 'i', '_', '_', '']
# 600
# percussion
# The word: ['p', 'e', 'r', 'c', 'u', 's', 's', 'i', 'o', '_', '']
# 300
# percussion
# The word: ['p', 'e', 'r', 'c', 'u', 's', 's', 'i', 'o', 'n', '']
# The word has been guessed! The round is over!
# {0: {'roundtotal': 3850, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}

# %%
print('\n Welcome to Wheel of Fortune!')
print("\n Let's start the game!")

from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random
round_total = 0

players={0:{"roundtotal":round_total,"gametotal":0,"name":""},
         1:{"roundtotal":round_total,"gametotal":0,"name":""},
         2:{"roundtotal":round_total,"gametotal":0,"name":""},
        }

roundNum = 0
round_winnings = 0
dictionary_list = []
turntext = ""
wheel_list = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
consonants = {"b", "c", "d", "f" "g", "h", "j", "k", "l", "m", "n", "p", "q", "r", "s", "t", "v", "w", "x", "y", "z"}
roundstatus = ""
finalroundtext = ""
player_list = []

print(type(vowels))


def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheel_list
    f = open('DATA TXT Files\wheeldata.txt')
    wheelvalue = f.read().split('\n')
    f.close()
    for value in range(0,len(wheelvalue)):
        wheel_list.append(wheelvalue[value])
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    global player_keys
    global playerNum
    players.update({0:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({1:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({2:{"roundtotal":0,"gametotal":round_winnings}})
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    getWord()
    playerNum = initPlayer
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)


# def guessletter(letter, playerNum): 
#     global players
#     global blankWord
#     # parameters:  take in a letter guess and player number
#     # Change position of found letter in blankWord to the letter instead of underscore 
#     # return goodGuess= true if it was a correct guess
#     # return count of letters in word. 
#     # ensure letter is a consonate.
    
#     return goodGuess, count

def spinWheel(player_keys):
    global wheel_list
    global players
    global vowels
    global spin_value
    global roundUnderscoreWord
    global round_total
    global consonant_value
    
    stillinTurn = True
    while stillinTurn is True:
        spin_value = random.choice(wheel_list)
        if spin_value == 'bankrupt':
            players.update({"roundtotal":0})
            stillinTurn = False
            print (spin_value)
            continue
        if spin_value == 'lose_a_turn':
            stillinTurn = False
            print(spin_value)
            continue
        else:
            consonant_value = int(spin_value)
            print(spin_value)
            guess = input('Guess your letter: ')
            if guess.isalpha() is False:
                print('Please guess a letter!')
                continue
            if guess in vowels:
                print('Please guess a consonant.')
                continue
            else:
                print(roundWord)
                if guess in roundWord:
                    pos = [i for i in range(len(roundWord)) if roundWord.startswith(guess,i)]
                    guess = list(guess)
                    for i in pos:
                        roundUnderscoreWord = roundUnderscoreWord[:i] + guess + roundUnderscoreWord[i + len(guess):]
                        print (f'The word: {roundUnderscoreWord}')
                        round_total = round_total+consonant_value
                        players.update({0:{"roundtotal":round_total, "gametotal":round_winnings}})
                        print(players)
                        continue
                    if "_" not in roundUnderscoreWord:
                        print('The word has been guessed! The round is over!')
                        break
                else:
                    print (f'The word: {roundUnderscoreWord}')
                    stillinTurn = False
    
    # Get random value for wheellist
    # Check for bankrupcy, and take action.
    # Check for lose turn
    # Get amount from wheel if not lose turn or bankruptcy
    # Ask user for letter guess
    # Use guessletter function to see if guess is in word, and return count
    # Change player round total if they guess right. 
        
    return stillinTurn


gameSetup()
wofRoundSetup()
spinWheel(player_keys)
gameSetup()
wofRoundSetup()
spinWheel(player_keys)

        #     if guess in vowels:
        #         print('Vowels cost 250.')
        #         players.update({0:{"roundtotal":{round_total-250}, "gametotal":round_winnings}})
        #         continue
# Out:
#  Welcome to Wheel of Fortune!
#
#  Let's start the game!
# <class 'set'>
# 450
# trumpet
# The word: ['_', '_', '_', '_', 'p', '_', '_', '']
# {0: {'roundtotal': 450, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# 900
# trumpet
# The word: ['t', '_', '_', '_', 'p', '_', '_', '']
# {0: {'roundtotal': 1350, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# The word: ['t', '_', '_', '_', 'p', '_', 't', '']
# {0: {'roundtotal': 2250, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# 850
# trumpet
# The word: ['t', 'r', '_', '_', 'p', '_', 't', '']
# {0: {'roundtotal': 3100, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# 200
# Please guess a consonant.
# 650
# trumpet
# The word: ['t', 'r', '_', 'm', 'p', '_', 't', '']
# {0: {'roundtotal': 3750, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# 250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\nolan\Desktop\Dev10 Training\M06 Python Basics\M06 Assessment\work.ipynb Cell 17 in <cell line: 209>()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=206'>207</a> gameSetup()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=207'>208</a> wofRoundSetup()
# --> <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=208'>209</a> spinWheel(player_keys)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=209'>210</a> gameSetup()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=210'>211</a> wofRoundSetup()
#
# c:\Users\nolan\Desktop\Dev10 Training\M06 Python Basics\M06 Assessment\work.ipynb Cell 17 in spinWheel(player_keys)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=167'>168</a> consonant_value = int(spin_value)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=168'>169</a> print(spin_value)
# --> <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=169'>170</a> guess = input('Guess your letter: ')
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=170'>171</a> if guess.isalpha() is False:
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X22sZmlsZQ%3D%3D?line=171'>172</a>     print('Please guess a letter!')
#
# File c:\Users\nolan\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File c:\Users\nolan\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('\n Welcome to Wheel of Fortune!')
print("\n Let's start the game!")

from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random
round_total = 0

players={0:{"roundtotal":round_total,"gametotal":0,"name":""},
         1:{"roundtotal":round_total,"gametotal":0,"name":""},
         2:{"roundtotal":round_total,"gametotal":0,"name":""},
        }

roundNum = 0
round_winnings = 0
dictionary_list = []
turntext = ""
wheel_list = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
consonants = {"b", "c", "d", "f" "g", "h", "j", "k", "l", "m", "n", "p", "q", "r", "s", "t", "v", "w", "x", "y", "z"}
roundstatus = ""
finalroundtext = ""
player_list = []
vowel_cost = 250


def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheel_list
    f = open('DATA TXT Files\wheeldata.txt')
    wheelvalue = f.read().split('\n')
    f.close()
    for value in range(0,len(wheelvalue)):
        wheel_list.append(wheelvalue[value])
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    global player_keys
    global playerNum
    players.update({0:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({1:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({2:{"roundtotal":0,"gametotal":round_winnings}})
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    getWord()
    playerNum = initPlayer
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)


def spinWheel(player_keys):
    global wheel_list
    global players
    global vowels
    global spin_value
    global roundUnderscoreWord
    global round_total
    global consonant_value
    gameSetup()
    wofRoundSetup()
    round_active = True
    while round_active is True:
        print("It's your turn Player!")
        print("================================")
        print("s: Spin the Wheel")
        print("b: Buy a vowel")
        print("g: guess the word")
        menu = input("What would you like to do")
        print(roundWord)
        stillinTurn = True
        if menu == "b":
            while stillinTurn is True:
                print('Vowels cost 250.')
                vowel_guess = input('What vowel would you like to buy?')
                if vowel_guess not in vowels:
                    print('Please guess a vowel')
                else:
                    if vowel_guess in roundWord:
                        pos = [i for i in range(len(roundWord)) if roundWord.startswith(vowel_guess,i)]
                        vowel_guess = list(vowel_guess)
                        for i in pos:
                            roundUnderscoreWord = roundUnderscoreWord[:i] + vowel_guess + roundUnderscoreWord[i + len(vowel_guess):]
                            print (f'The word: {roundUnderscoreWord}')
                            round_total = round_total - vowelcost
                            players.update({0:{"roundtotal":round_total, "gametotal":round_winnings}})
                            print(players)
                            continue
                        if "_" not in roundUnderscoreWord:
                            print('The word has been guessed! The round is over!')
                            round_active = False
                        else:
                            print (f'The word: {roundUnderscoreWord}')
                            stillinTurn = False
                            break
            continue
        if menu == 's':
            while stillinTurn is True:
                spin_value = random.choice(wheel_list)
                if spin_value == 'bankrupt':
                    players.update({"roundtotal":0})
                    stillinTurn = False
                    print (spin_value)
                    continue
                if spin_value == 'lose_a_turn':
                    stillinTurn = False
                    print(spin_value)
                    continue
                else:
                    consonant_value = int(spin_value)
                    print(spin_value)
                    guess = input('Guess your letter: ')
                    if guess.isalpha() is False:
                        print('Please guess a letter!')
                        continue
                    # if guess in vowels:
                    #     print('Please guess a consonant.')
                        # continue
                    else:
                        if guess in roundWord:
                            pos = [i for i in range(len(roundWord)) if roundWord.startswith(guess,i)]
                            guess = list(guess)
                            for i in pos:
                                roundUnderscoreWord = roundUnderscoreWord[:i] + guess + roundUnderscoreWord[i + len(guess):]
                                print (f'The word: {roundUnderscoreWord}')
                                round_total = round_total+consonant_value
                                players.update({0:{"roundtotal":round_total, "gametotal":round_winnings}})
                                print(players)
                                continue
                            if "_" not in roundUnderscoreWord:
                                print('The word has been guessed! The round is over!')
                                stillinTurn = False
                                round_active = False
                        else:
                            print (f'The word: {roundUnderscoreWord}')
                            break
            continue
        else:
            print("Please select a valid menu option\n")
            continue
        
        # Get random value for wheellist
        # Check for bankrupcy, and take action.
        # Check for lose turn
        # Get amount from wheel if not lose turn or bankruptcy
        # Ask user for letter guess
        # Use guessletter function to see if guess is in word, and return count
        # Change player round total if they guess right. 
            
        return stillinTurn



spinWheel(player_keys)
# Out:
#  Welcome to Wheel of Fortune!
#
#  Let's start the game!
# It's your turn Player!
# ================================
# s: Spin the Wheel
# b: Buy a vowel
# g: guess the word
# saxophone
# Please select a valid menu option
#
# It's your turn Player!
# ================================
# s: Spin the Wheel
# b: Buy a vowel
# g: guess the word
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\nolan\Desktop\Dev10 Training\M06 Python Basics\M06 Assessment\work.ipynb Cell 18 in <cell line: 236>()
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=223'>224</a>         # Get random value for wheellist
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=224'>225</a>         # Check for bankrupcy, and take action.
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=225'>226</a>         # Check for lose turn
#    (...)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=228'>229</a>         # Use guessletter function to see if guess is in word, and return count
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=229'>230</a>         # Change player round total if they guess right.
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=231'>232</a>         return stillinTurn
# --> <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=235'>236</a> spinWheel(player_keys)
#
# c:\Users\nolan\Desktop\Dev10 Training\M06 Python Basics\M06 Assessment\work.ipynb Cell 18 in spinWheel(player_keys)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=148'>149</a> print("b: Buy a vowel")
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=149'>150</a> print("g: guess the word")
# --> <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=150'>151</a> menu = input("What would you like to do")
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=151'>152</a> print(roundWord)
#     <a href='vscode-notebook-cell:/c%3A/Users/nolan/Desktop/Dev10%20Training/M06%20Python%20Basics/M06%20Assessment/work.ipynb#X23sZmlsZQ%3D%3D?line=152'>153</a> stillinTurn = True
#
# File c:\Users\nolan\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File c:\Users\nolan\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
print('\n Welcome to Wheel of Fortune!')
print("\n Let's start the game!")

from config import dictionaryloc
from config import turntextloc
from config import wheeltextloc
from config import maxrounds
from config import vowelcost
from config import roundstatusloc
from config import finalprize
from config import finalRoundTextLoc

import random
round_total = 0

players={0:{"roundtotal":round_total,"gametotal":0,"name":""},
         1:{"roundtotal":round_total,"gametotal":0,"name":""},
         2:{"roundtotal":round_total,"gametotal":0,"name":""},
        }

roundNum = 0
round_winnings = 0
dictionary_list = []
turntext = ""
wheel_list = []
roundWord = ""
blankWord = []
vowels = {"a", "e", "i", "o", "u"}
consonants = {"b", "c", "d", "f" "g", "h", "j", "k", "l", "m", "n", "p", "q", "r", "s", "t", "v", "w", "x", "y", "z"}
roundstatus = ""
finalroundtext = ""
player_list = []
vowel_cost = 250


def readDictionaryFile():
    global dictionary
    f = open('DATA TXT Files\dictionary.txt')
    dictionary = f.read().split('\n')
    f.close()
    for word in range(0,len(dictionary)):
        dictionary_list.append(dictionary[word])
    # Read dictionary file in from dictionary file location
    # Store each word in a list.

  
def readTurnTxtFile():
    global turntext
    f = open('DATA TXT Files\\turntext.txt')
    turntext = f.read()
    f.close()      
    #read in turn intial turn status "message" from file

        
def readFinalRoundTxtFile():
    global finalroundtext  
    f = open('DATA TXT FILES\\finalround.txt')
    finalroundtext = f.read()
    f.close()
    #read in turn intial turn status "message" from file


def readRoundStatusTxtFile():
    global roundstatus
    f = open('DATA TXT Files\\roundstatus.txt')
    roundstatus = f.read()
    f.close()
    # read the round status  the Config roundstatusloc file location 


def readWheelTxtFile():
    global wheel_list
    f = open('DATA TXT Files\wheeldata.txt')
    wheelvalue = f.read().split('\n')
    f.close()
    for value in range(0,len(wheelvalue)):
        wheel_list.append(wheelvalue[value])
    # read the Wheel name from input using the Config wheelloc file location 

    
def getPlayerInfo():
    global player_list
    for i in range(1,4):
        player_list.append([i])
    # read in player names from command prompt input


def gameSetup():
    # Read in File dictionary
    # Read in Turn Text Files
    global turntext
    global dictionary
        
    readDictionaryFile()
    readTurnTxtFile()
    readWheelTxtFile()
    getPlayerInfo()
    readRoundStatusTxtFile()
    readFinalRoundTxtFile() 
    
def getWord():
    global dictionary
    global roundWord
    global roundUnderscoreWord
    roundWord = random.choice(dictionary_list)
    roundUnderscoreWord = '_ ' * len(roundWord)
    roundUnderscoreWord = roundUnderscoreWord.split(' ')
    return roundWord, roundUnderscoreWord
    #choose random word from dictionary
    #make a list of the word with underscores instead of letters.

def wofRoundSetup():
    global players
    global roundWord
    global blankWord
    global player_list
    global initPlayer
    global player_keys
    global playerNum
    players.update({0:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({1:{"roundtotal":0,"gametotal":round_winnings}})
    players.update({2:{"roundtotal":0,"gametotal":round_winnings}})
    player_list = list(players.keys())
    player_keys = random.choice(player_list)
    initPlayer = [x+1 for x in {player_keys}]
    getWord()
    playerNum = initPlayer
    return initPlayer
    # Set round total for each player = 0
    # Return the starting player number (random)
    # Use getWord function to retrieve the word and the underscore word (blankWord)


def spinWheel(player_keys):
    global wheel_list
    global players
    global vowels
    global spin_value
    global roundUnderscoreWord
    global round_total
    global consonant_value
    gameSetup()
    wofRoundSetup()
    round_active = True
    while round_active is True:
        print("It's your turn Player!")
        print("================================")
        print("s: Spin the Wheel")
        print("b: Buy a vowel")
        print("g: guess the word")
        menu = input("What would you like to do? ")
        print(roundWord)
        stillinTurn = True
        if menu == "b":
            while stillinTurn is True:
                print('Vowels cost 250.')
                vowel_guess = input('What vowel would you like to buy? ')
                if vowel_guess not in vowels:
                    print('Please guess a vowel')
                else:
                    if vowel_guess in roundWord:
                        pos = [i for i in range(len(roundWord)) if roundWord.startswith(vowel_guess,i)]
                        vowel_guess = list(vowel_guess)
                        for i in pos:
                            roundUnderscoreWord = roundUnderscoreWord[:i] + vowel_guess + roundUnderscoreWord[i + len(vowel_guess):]
                            print (f'The word: {roundUnderscoreWord}')
                            round_total = round_total - vowelcost
                            players.update({0:{"roundtotal":round_total, "gametotal":round_winnings}})
                            print(players)
                            continue
                        if "_" not in roundUnderscoreWord:
                            print('The word has been guessed! The round is over!')
                            round_active = False
                            stillinTurn = False
                        else:
                            print (f'The word: {roundUnderscoreWord}')
                            stillinTurn = False
                            break
            continue
        if menu == 's':
            while stillinTurn is True:
                spin_value = random.choice(wheel_list)
                if spin_value == 'bankrupt':
                    players.update({"roundtotal":0})
                    stillinTurn = False
                    print (spin_value)
                    continue
                if spin_value == 'lose_a_turn':
                    stillinTurn = False
                    print(spin_value)
                    continue
                else:
                    consonant_value = int(spin_value)
                    print(spin_value)
                    guess = input('Guess your letter: ')
                    if guess.isalpha() is False:
                        print('Please guess a letter!')
                        continue
                    # if guess in vowels:
                    #     print('Please guess a consonant.')
                        # continue
                    else:
                        if guess in roundWord:
                            pos = [i for i in range(len(roundWord)) if roundWord.startswith(guess,i)]
                            guess = list(guess)
                            for i in pos:
                                roundUnderscoreWord = roundUnderscoreWord[:i] + guess + roundUnderscoreWord[i + len(guess):]
                                print (f'The word: {roundUnderscoreWord}')
                                round_total = round_total+consonant_value
                                players.update({0:{"roundtotal":round_total, "gametotal":round_winnings}})
                                print(players)
                                continue
                            if "_" not in roundUnderscoreWord:
                                print('The word has been guessed! The round is over!')
                                stillinTurn = False
                                round_active = False
                        else:
                            print (f'The word: {roundUnderscoreWord}')
                            stillinTurn = False
                            break           
            continue
        else:
            print("Please select a valid menu option\n")
            continue
        
        # Get random value for wheellist
        # Check for bankrupcy, and take action.
        # Check for lose turn
        # Get amount from wheel if not lose turn or bankruptcy
        # Ask user for letter guess
        # Use guessletter function to see if guess is in word, and return count
        # Change player round total if they guess right. 
            
        return stillinTurn

spinWheel(player_list)
# Out:
#  Welcome to Wheel of Fortune!
#
#  Let's start the game!
# It's your turn Player!
# ================================
# s: Spin the Wheel
# b: Buy a vowel
# g: guess the word
# piano
# 900
# The word: ['p', '_', '_', '_', '_', '']
# {0: {'roundtotal': 900, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# 750
# The word: ['p', '_', '_', 'n', '_', '']
# {0: {'roundtotal': 1650, 'gametotal': 0}, 1: {'roundtotal': 0, 'gametotal': 0}, 2: {'roundtotal': 0, 'gametotal': 0}}
# 600
# The word: ['p', '_', '_', 'n', '_', '']
